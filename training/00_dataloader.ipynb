# %% [markdown]
# ### 1 Download datasets

# %% [markdown]
# ### Kaggle dataset

# %%
# train.csv
! gdown 19gyTA8S9wXPlxkyU0mZ_raJO62ny-vpo

# test.csv
! gdown 1NqChJSt70NvgInNvYEyh2GTsBfpXUNuj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19gyTA8S9wXPlxkyU0mZ_raJO62ny-vpo
# To: /content/train.csv
# 100% 988k/988k [00:00<00:00, 142MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NqChJSt70NvgInNvYEyh2GTsBfpXUNuj
# To: /content/test.csv
# 100% 421k/421k [00:00<00:00, 103MB/s]

# %% [markdown]
# ### CrisisMMD dataset

# %%
# Download dataset
! gdown 1wi_kAVETQHQyGA-thBhP7VY1L2jD5quI

# Unzip
! tar -xzf "CrisisMMD_v2.0.tar.gz"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1wi_kAVETQHQyGA-thBhP7VY1L2jD5quI
# From (redirected): https://drive.google.com/uc?id=1wi_kAVETQHQyGA-thBhP7VY1L2jD5quI&confirm=t&uuid=ead454b1-620f-41bd-b84d-df61361cdfd9
# To: /content/CrisisMMD_v2.0.tar.gz
# 100% 1.90G/1.90G [00:22<00:00, 83.3MB/s]

# %% [markdown]
# ### 2 Clone Github repository

# %%
# !git clone https://github.com/brian-w-zhang/Data-Science-Project.git
# Out:
# Cloning into 'Data-Science-Project'...
# remote: Enumerating objects: 142, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 142 (delta 70), reused 96 (delta 37), pack-reused 6 (from 1)
# Receiving objects: 100% (142/142), 6.49 MiB | 12.91 MiB/s, done.
# Resolving deltas: 100% (71/71), done.

# %%
import os, sys

# Go to the repo root (adjust path if needed)
# %cd /content/Data-Science-Project

# Make sure repo root is on sys.path
repo_root = os.getcwd()
if repo_root not in sys.path:
    sys.path.append(repo_root)

print("Using repo_root:", repo_root)
# Out:
# /content/Data-Science-Project
# Using repo_root: /content/Data-Science-Project

# %%
# !git pull
# Out:
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 10 (delta 6), reused 10 (delta 6), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 219.74 KiB | 5.63 MiB/s, done.
# From https://github.com/brian-w-zhang/Data-Science-Project
#    72371e7..0373ad6  feat/curves -> origin/feat/curves
# Updating 72371e7..0373ad6
# Fast-forward
#  data/crisismmd.py                     |  17 ++-
#  training/00_dataloader.ipynb          |  60 ++++-----
#  training/01_text_branch_train.ipynb   | 221 +++++++++++++++++++++++++------
#  training/02_vision_branch_train.ipynb | 236 ++++++++++++++++++++++++++++++----
#  training/03_fusion_layer_train.ipynb  | 130 ++++++++++---------
#  training/04_datasaver.ipynb           |  20 ++-
#  6 files changed, 515 insertions(+), 169 deletions(-)
