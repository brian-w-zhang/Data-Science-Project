# %% [markdown]
# ### 1 Download datasets

# %% [markdown]
# ### Kaggle dataset

# %%
# train.csv
! gdown 19gyTA8S9wXPlxkyU0mZ_raJO62ny-vpo

# test.csv
! gdown 1NqChJSt70NvgInNvYEyh2GTsBfpXUNuj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19gyTA8S9wXPlxkyU0mZ_raJO62ny-vpo
# To: /content/train.csv
# 100% 988k/988k [00:00<00:00, 138MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1NqChJSt70NvgInNvYEyh2GTsBfpXUNuj
# To: /content/test.csv
# 100% 421k/421k [00:00<00:00, 124MB/s]

# %% [markdown]
# ### CrisisMMD dataset

# %%
# Download dataset
! gdown 1wi_kAVETQHQyGA-thBhP7VY1L2jD5quI

# Unzip
! tar -xzf "CrisisMMD_v2.0.tar.gz"
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for google.colab:colab:c55f5dda-0544-46aa-8fdb-d806c0c9ed46

# %% [markdown]
# ### 2 Clone Github repository

# %%
# !git clone -b feat/refactor --single-branch https://github.com/brian-w-zhang/Data-Science-Project.git
# Out:
# Cloning into 'Data-Science-Project'...
# remote: Enumerating objects: 85, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 85 (delta 33), reused 59 (delta 20), pack-reused 6 (from 1)
# Receiving objects: 100% (85/85), 6.26 MiB | 17.52 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %%
import os, sys

# Go to the repo root (adjust path if needed)
# %cd /content/Data-Science-Project

# Make sure repo root is on sys.path
repo_root = os.getcwd()
if repo_root not in sys.path:
    sys.path.append(repo_root)

print("Using repo_root:", repo_root)
# Out:
# /content/Data-Science-Project
# Using repo_root: /content/Data-Science-Project

# %%
# !git pull
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 7 (delta 5), reused 7 (delta 5), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 5.83 KiB | 2.91 MiB/s, done.
# From https://github.com/brian-w-zhang/Data-Science-Project
#    4ee76cb..8e5c304  feat/refactor -> origin/feat/refactor
# Updating 4ee76cb..8e5c304
# Fast-forward
#  models/vision_branch.py             |  13 ++++
#  training/00_dataloader.ipynb        | 148 ++++++++++++++++++++++--------------
#  training/01_text_branch_train.ipynb | 116 ++++++++++++++++++++++------
#  3 files changed, 197 insertions(+), 80 deletions(-)
